# %%
import pandas as pd
import numpy as np

# %%
filename = "Airbnb Data/airbnb prices.csv"

# %%
airbnb = pd.read_csv(filename)

# %%
airbnb
# Out:
#         room_id  survey_id    host_id     room_type  country       city  \
# 0      10176931       1476   49180562   Shared room      NaN  Amsterdam
# 1       8935871       1476   46718394   Shared room      NaN  Amsterdam
# 2      14011697       1476   10346595   Shared room      NaN  Amsterdam
# 3       6137978       1476    8685430   Shared room      NaN  Amsterdam
# 4      18630616       1476   70191803   Shared room      NaN  Amsterdam
# ...         ...        ...        ...           ...      ...        ...
# 18718  17789893       1476   47501089  Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870  Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632  Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569  Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013  Private room      NaN  Amsterdam
#
#        borough             neighborhood  reviews  overall_satisfaction  \
# ...

# %%
airbnb.drop(columns = ["country", "borough", "bathrooms", "minstay"], inplace = True)

# %%
airbnb
# Out:
#         room_id  survey_id    host_id     room_type       city  \
# 0      10176931       1476   49180562   Shared room  Amsterdam
# 1       8935871       1476   46718394   Shared room  Amsterdam
# 2      14011697       1476   10346595   Shared room  Amsterdam
# 3       6137978       1476    8685430   Shared room  Amsterdam
# 4      18630616       1476   70191803   Shared room  Amsterdam
# ...         ...        ...        ...           ...        ...
# 18718  17789893       1476   47501089  Private room  Amsterdam
# 18719  16877166       1476   67093870  Private room  Amsterdam
# 18720  19859427       1476   29724632  Private room  Amsterdam
# 18721  17132164       1476  115156569  Private room  Amsterdam
# 18722   7605782       1476   39503013  Private room  Amsterdam
#
#                   neighborhood  reviews  overall_satisfaction  accommodates  \
# 0      De Pijp / Rivierenbuurt        7                   4.5             2
# ...
